# %% [markdown]
# # Homework for Week 9

# %% [markdown]
# ## Homework 1 - Find the Tables
#
# In the document called <a href="https://www.dropbox.com/s/af5eob7htijsb81/dod.pdf?dl=0">dod.pdf</a>
#
# 1. Capture the table on page 4-3 in Chapter 4 that gives the FY 2020 Defense Budget for Major Weapons Programs. (Figure 4.1) and download it as a CSV.
#
# 2. Capture the table on page 4-9 in Chapter 4 that gives the FY 2020 Defense Budget for Nuclear Modernization (figure 4.3) and download it as a CSV.

# %%
pip install -q tabula-py
# Out:
#      |████████████████████████████████| 11.7MB 30.1MB/s

# %%
## import unzipper

from zipfile import ZipFile
import glob
import os  ## allows you to navigate, create, delete folders
from pathlib import Path ## allows to create paths to files and folders
import tabula
import pandas as pd
## in order to export our file to our computer drive, you need this only in Colab:
# from google.colab import files

# %%
## COLAB ONLY
# files.upload()
# Out:
#      <input type="file" id="files-9689241d-2eac-4de2-aae3-b98d074d8738" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9689241d-2eac-4de2-aae3-b98d074d8738">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving homework_fuds.zip to homework_fuds.zip
# {'homework_fuds.zip': b'PK\x03\x04\x14\x00\x00\x00\x00\x00ddZQ\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x0e\x00 \x00homework_fuds/UT\r\x00\x07\xbc\xfa\x96_\xbd\xfa\x96_\xf7\xfa\x96_ux\x0b\x00\x01\x04j\xb6\x9bI\x04\x81\xd7\x9b\x19PK\x03\x04\x14\x00\x08\x00\x08\x00ddZQ\x00\x00\x00\x00\x00\x00\x00\x00\xb2\x00\x00\x00\x18\x00 \x00__MACOSX/._homework_fudsUT\r\x00\x07\xbc\xfa\x96_\xbd\xfa\x96_\xfd\xfa\x96_ux\x0b\x00\x01\x04j\xb6\x9bI\x04\x81\xd7\x9b\x19c`\x15cg`b`\xf0MLV\xf0\x0fV\x88P\x80\x02\x90\x18\x03\'\x10\x1b\x01q\x03\x10\x83\xf8\x9b\x18\x88\x02\x8e!!AP&H\xc7\x0c \x96BS\xc2\x88\x10\x17J\xce\xcf\xd5K)\xca/H\xca\xaf\xd0K,))*\x06)\xe0\x12\xe2\x12\xf0p\xe5_\xf9u\xdd\xb74\xb0\x0e\x8eB\t\x81\xc7G\x7fNa\x03\x00PK\x07\x08\xdd\x95\xcdCa\x00\x00\x00\xb2\x00\x00\x00PK\x03\x04\x14\x00\x08\x00\x08\x00ddZQ\x00\x00\x00\x00\x00\x00\x00\x00\x04(\x00\x00\x17\x00 \x00homework_fuds/.DS_StoreUT\r\x00\x07\xbc\xfa\x96_\xbc\xfa\x96_\xbc\xfa\x96_ux\x0b\x00\x01\x04j\xb6\x9bI\x04\x81\xd7\x9b\x19\xedZ_l\x14E\x18\xff\xbek){\x0b\xd8\xe9\x1f\xc0#\x1cnii\n\x14\xbcRH+\xa1r\xbd\x9e\x92j\xb1\x95+m\xa1\xd0v\xefv\xdb\xae\xec\xed\x9e\xb7{w\x94Rl\xe2\x8b\x11\xd4\xf8\xa04\xfey\x11\xff\xc4\xe0\x93\x06\xdf\x8c\xa2\x0f\x9a\xf87\x82\x115<\x18\xe2\x83\xbe\xf8h4\x928{3\x07\xc7q\xd7\x14_j\xec\xfe\x92\xb9\xdf\xce\xcc\xf7\xed\xcc7\xf3\x9b\x9d\x9b\xdb\x03\x00\x0c\xa
14U\x11\xea\x83Ml\xfc\xb2#\xe0%\xce\xa6\xe5\x83\x8d\xb0\x13\xf6@\x1f\x1c\xa2S\x9f\x813\xf0\x02\xbc\x08\xaf\xc1yx\x0f>\x80O\xe0+\xf8\x1a\xbe\x81Kp\x05~\x86_\xe1w\xf8\x13\xfe\x82\xbf\xe1:V`%\x12\xac\xc2\x1a\x94p3n\xc1\xad\xd8\x86A\xec\xc4\x10\x86\xb1\x1b\x0f`\x04\xfbq\x00\x87QA\x15\xc7q\x12\r\xcc\xe0q\x9c\xc2i|\x12\xcf\xe03\xf8,>\x8f/\xe19|\x1d\xdf\xc0\xb7\xf0}\xfc\x10?\xc2\x8b\xf89~\x81\xdf\xe1\x8f\xf8\x13\xeb\xa7\'\xb7\x12\xf6\xdf\xba\x10\xf0\xea\xbc\xe2\xe5\xcb\xde3RL\xbc\xfe\x07\xf7\x89\xa1E\x15\xef\x0f+\x9d\x99\xab\xaa\xae\xa9]\xbd\xa1\xbei\xdb\x8e\xb6=\x9d7&\xb5`\x1e\xf3%\x95U\x11\x93IV>9yd\'\xf3VM\xd2\xd9\xf7\xad\x13\xd7\xfb\x0fR3\xf5x\xe1z\xc8)\x9e,w\xf4$d\xad\xef\xf1\xd7\xf9\x89#$\x96m\xf07\xfa\x89\x87j\x9de7\xfb\xb7\x8a\xa4\x8c*\xd9\x9b\xcdn\x17\x03~\xb2\x8c\x8a\x96\xd5\xb6\x8a\xbbDRNU\xcdj\xdb\xc5\xdd~RA\xf5\xcbj;\xc4\xbd"\x01g\xdd\xb1\xea\x90\xbfQ$(x\x0b\xd5XR\x8bo\xc3\xbbp\x11\xbe\x84o\xa9\x ...

# %%
## Let's pull in our DOD pdf 
path_01 = "dod.pdf"

# %%
## capture both tables using range of numbers (remember NO spaces in specifying numbers)
dod_table_1 = tabula.read_pdf(path_01, pages = "48,54"  )

# %%
## let print out Figure 4.1
dod_table_1[0]

# %%
## let print out Figure 4.3
dod_table_1[1]

# %%
#turn figure 4.1 into pandas dataframe
df = pd.DataFrame(dod_table_1[0])
df

# %%
## Export figure 4.1 and download as CSV file
filename = "major-weapons-programs.csv"
df.to_csv(filename, encoding='utf-8', index=False)
files.download(filename) ## colab command

# %%
#turn figure 4.3 into pandas dataframe
df2 = pd.DataFrame(dod_table_1[1])
df2

# %%
## Export figure 4.3 and download as CSV file
filename = "nuclear-modernization.csv"
df2.to_csv(filename, encoding='utf-8', index=False)
files.download(filename) ## colab command

# %% [markdown]
# ## Homework 2 - Multi-State FUDS
#
# - Access <a href="https://www.dropbox.com/s/mjf3k5x1cjeqnc0/homework_fuds.zip?dl=0">homework_fuds.zip</a>.
#
# - Manually unzip only ```homework_fuds.zip```. It contains three additional zip files. **DO NOT** manually unzip them.
#
# - Write a script that opens each zip folder, finds only the pdf file it contains and grab all the tables...
#
# - The final product should be a single csv file that contains the FUDS data for all three states (Alaska, New York and West Virginia).

# %%
myfolders = sorted(glob.glob('*.zip'))
myfolders
# Out:
# ['homework_fuds.zip']

# %%
for folder_name in myfolders:

    ## unzip and gather only the pdf files
    with ZipFile(folder_name, 'r') as my_folder_object:
      file_names_list = my_folder_object.namelist()
      ## iterate over the file names
      for file_name in file_names_list:
        if file_name.endswith('.pdf'):
            my_folder_object.extract(file_name, "pdfs")
            print(f"Found this image: {file_name}")
# Out:
# Found this image: homework_fuds/alaska_fuds/USACE 2018_FUDS_Inventory_Alaska.pdf
# Found this image: __MACOSX/homework_fuds/alaska_fuds/._USACE 2018_FUDS_Inventory_Alaska.pdf
# Found this image: homework_fuds/ny_fuds/FUDS_NY.pdf
# Found this image: __MACOSX/homework_fuds/ny_fuds/._FUDS_NY.pdf
# Found this image: homework_fuds/west_virginia_fuds/FUDS_Inventory_WestVirginia.pdf
# Found this image: __MACOSX/homework_fuds/west_virginia_fuds/._FUDS_Inventory_WestVirginia.pdf

# %%
ls
# Out:
# homework_fuds.zip  pdfs/  sample_data/

# %%
## gather all pdfs in a list
myfiles = sorted(glob.glob('pdfs/homework_fuds/*/*.pdf'))
myfiles
# Out:
# ['pdfs/homework_fuds/alaska_fuds/USACE 2018_FUDS_Inventory_Alaska.pdf',
#  'pdfs/homework_fuds/ny_fuds/FUDS_NY.pdf',
#  'pdfs/homework_fuds/west_virginia_fuds/FUDS_Inventory_WestVirginia.pdf']

# %%
## write function to combine tabula tables into a single csv
def combine_tables(list_name,filename):
  '''
  Takes tables produced by tabula and combines into a single CSV
  CSV extension needed!
  Arguments: name of list produced by tabula and the CSV name you want (in quotes as a string)
  '''
  # dataframes = [pd.DataFrame(a_table) for a_table in list_name] ## list comprehension to turn each tabula table into a dataframe
  df = pd.concat(list_name) ## join/concat all the dataframes into one dataframe
  df.reset_index(inplace = True, drop = True) ## reset index, drop what was there before
  df.to_csv(filename, encoding='utf-8', index=False) ## convert that single dataframe into a csv
#   files.download(filename) ## download it COLAB ONLY!
  print(f"{filename} is in your downloads folder!")

# %%
### export each pdf as a table
counter = 1
for file in myfiles:
    print(file)
    ## get all the pages
    contribs_tables = tabula.read_pdf(file, pages = "all")
    print(type(contribs_tables))
    combine_tables(contribs_tables, f"table_{counter}.csv")  ## using function
    counter+=1
# Out:
# pdfs/homework_fuds/alaska_fuds/USACE 2018_FUDS_Inventory_Alaska.pdf
# Got stderr: Jun 02, 2021 7:07:30 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider loadDiskCache
# WARNING: New fonts found, font cache will be re-built
# Jun 02, 2021 7:07:30 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Building on-disk font cache, this may take a while
# Jun 02, 2021 7:07:30 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Finished building on-disk font cache, found 17 fonts
# <class 'list'>
# table_1.csv is in your downloads folder!
# pdfs/homework_fuds/ny_fuds/FUDS_NY.pdf
# Got stderr: Jun 02, 2021 7:07:41 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# Jun 02, 2021 7:07:41 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats
# <class 'list'>
# table_2.csv is in your downloads folder!
# pdfs/homework_fuds/west_virginia_fuds/FUDS_Inventory_WestVirginia.pdf
# Got stderr: Jun 02, 2021 7:07:48 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# Jun 02, 2021 7:07:48 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats
# <class 'list'>
# table_3.csv is in your downloads folder!

# %%
### gather all csv files as a list
all_filenames = [a_file for a_file in glob.glob('*.csv')]
all_filenames
# Out:
# ['table_2.csv', 'table_3.csv', 'table_1.csv']

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(a_csv_file) for a_csv_file in all_filenames ])
#export to csv
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8')
